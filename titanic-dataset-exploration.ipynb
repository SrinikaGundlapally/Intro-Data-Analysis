# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
train = pd.read_csv('/kaggle/input/titanic/train.csv')
test = pd.read_csv('/kaggle/input/titanic/test.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
##statistical info
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
## datatype info
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
## categorical attributes
sns.countplot(data=train, x='Survived')
plt.title("Survival Count")
plt.show()

# %%
sns.countplot(data=train, x='Pclass')
plt.title("Relationship between Count and Passenger Class")
plt.show()

# %%
sns.countplot(data=train, x='Sex')
plt.title("Count of Male vs Female Passengers")
plt.show()

# %%
sns.countplot(data=train, x='SibSp')
plt.title("Relation between Count and Number of Siblings/Spouses on Titanic")
plt.show()

# %%
sns.countplot(data=train, x='Parch')
plt.title("Relationship between Count and # of Parents / Children aboard the Titanic")
plt.show()

# %%
sns.countplot(data=train, x='Embarked')
plt.title("Port of Embarkation vs Count")
plt.show()

# %%
## Numerical attributes
sns.distplot(train['Age'])
plt.title("Density based on Passenger Age")
plt.show()

# %%
## reproccessing should happen--right skewed must be uniform bell curve
sns.distplot(train['Fare'])
plt.title("Density based on Fare")
plt.show()

# %%
##compare ticket class & price
class_fare = train.pivot_table(index='Pclass', values='Fare', aggfunc=np.sum)
class_fare.plot(kind='bar')
plt.xlabel('Pclass')
plt.ylabel('Total Fare')
plt.title('Ticket Class vs Price')
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(data=train, x='Pclass', y='Fare', hue='Survived')
plt.title("Ticket Class vs Fare")
plt.show()

# %%
sns.barplot(data=train, x='Survived', y='Fare', hue='Pclass')
plt.title("Impact of Ticket Class and Fare Price on Survival Rates")
plt.show()

# %%
sns.barplot(x='Sex', y='Survived', data=train)
plt.title('Survival Rate by Gender (0=Female, 1=Male)')
plt.show()

# %%
sns.barplot(x='Pclass', y='Survived', data=train)
plt.title('Survival Rate by Ticket Class')
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
train_len = len(train)
#combine two dataframes
df = pd.concat([train,test], axis=0) ##concat in rows
df = df.reset_index(drop=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  39.0      0      0            PC 17758  108.9000  C105        C
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307   NaN      0      0              359309    8.0500   NaN        S
# 1308   NaN      1      1                2668   22.3583   NaN        C

# %%
## find the null values
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# drop or delete the cabin column
df = df.drop(columns=['Cabin'], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['Age'].mean()
# Out:
# np.float64(29.881137667304014)

# %%
# fill missing values using mean of that numerical column
df['Age']= df['Age'].fillna(df['Age'].mean())
df['Fare']= df['Fare'].fillna(df['Fare'].mean())

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
#fill missing values using mode of the categorical column
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# # Log transformation for uniform data distribution

# %%
sns.distplot(df['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
df['Fare'] = np.log(df['Fare']+1)

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(15, 9))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Embarked
# 0      0         A/5 21171  2.110213        S
# 1      0          PC 17599  4.280593        C
# 2      0  STON/O2. 3101282  2.188856        S
# 3      0            113803  3.990834        S
# 4      0            373450  2.202765        S

# %%
## drop unnecessary columns
df = df.drop(columns=['Name', 'Ticket'], axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0            1       0.0       3    male  22.0      1      0  2.110213
# 1            2       1.0       1  female  38.0      1      0  4.280593
# 2            3       1.0       3  female  26.0      0      0  2.188856
# 3            4       1.0       1  female  35.0      1      0  3.990834
# 4            5       0.0       3    male  35.0      0      0  2.202765
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# # Convert Types w/ Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Sex', 'Embarked']
le = LabelEncoder()

for col in cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0            1       0.0       3    1  22.0      1      0  2.110213         2
# 1            2       1.0       1    0  38.0      1      0  4.280593         0
# 2            3       1.0       3    0  26.0      0      0  2.188856         2
# 3            4       1.0       1    0  35.0      1      0  3.990834         2
# 4            5       0.0       3    1  35.0      0      0  2.202765         2
